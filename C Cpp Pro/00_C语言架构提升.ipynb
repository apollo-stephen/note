# %% [markdown]
# # C语言架构提升

# %% [markdown]
# ## 1.架构视角
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.linux下的vim操作
#
# ![image.png](attachment:image.png)

# %% [markdown]
# linux无桌面系统，远程连接运维的时候，vim是最常用的编辑器，掌握vim的操作可以大大提升效率。gcc是linux下的c语言编译器，掌握gcc的使用可以更好地编译和调试c语言程序。gdb是linux下的c语言调试器，掌握gdb的使用可以更好地调试c语言程序。
